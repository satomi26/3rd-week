# %%
import pandas as pd

# %%
df = pd.read_csv("movies_2.csv")
df.head(10)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
# 5        6                  Uncle Buck          PG  15000000.0   79258538.0
# 6        7     When Harry Met Sally...           R  16000000.0   92800000.0
# 7        8          Dead Poets Society          PG  16400000.0  235860116.0
# 8        9                  Parenthood       PG-13  20000000.0  126297830.0
# 9       10             Lethal Weapon 2           R  25000000.0  227853986.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# ...

# %%
df.tail(10)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 606      607              Spider-Man: Far from Home       PG-13  160000000.0
# 607      608                                  Dumbo          PG  170000000.0
# 608      609                         Captain Marvel       PG-13  175000000.0
# 609      610                                Aladdin          PG  183000000.0
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# ...

# %%
# the number of rows and columns present in the data set 
df.shape
# Out:
# (616, 11)

# %%
# columns present in the data set, along with the data type
df.info
# Out:
# <bound method DataFrame.info of      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
df.isna().sum()
# Out:
# MovieID           0
# Title             1
# MPAA Rating       1
# Budget            1
# Gross             1
# Release Date      1
# Genre             1
# Runtime           1
# Rating          108
# Rating Count    108
# Summary         120
# dtype: int64

# %%
df_one = df.drop(["Summary"], axis = 1)

# %%
df_two = df_one.rename(columns={"MovieID": "movie_id", "Title": "title","MPAA Rating": "mpaa_rating","Budget": "budget", "Gross": "gross", "Release Date": "release_date","Genre": "genre","Runtime": "runtime", "Rating":"rating", "Rating Count":"rating_count"})
df_two
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
# 615         0                                    NaN         NaN          NaN
#
# ...

# %%
df_three = df_two[:-1]
df_three
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
df_three.isna().sum()
# Out:
# movie_id          0
# title             0
# mpaa_rating       0
# budget            0
# gross             0
# release_date      0
# genre             0
# runtime           0
# rating          107
# rating_count    107
# dtype: int64

# %%
# we have missing data in column "rating" and "rating count"
# find the mean and median from "rating" and "rating count"

df_mean = df_three.mean()
df_mean
# Out:
# movie_id        3.080000e+02
# budget          9.491710e+07
# gross           4.453221e+08
# runtime         1.186423e+02
# rating          6.917323e+00
# rating_count    3.392521e+05
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-5a1886123ecb> in <module>
# ----> 1 df_mean("rating")
#
# TypeError: 'Series' object is not callable

# %%
# use fillna() method to replace the missing values of Rating with their median

filled_df = df_three["rating"].fillna(value = 6.9, inplace=True)
print("filled_df")
# Out:
# filled_df
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df_three.shape
# Out:
# (615, 10)

# %%
df_four = df_three.drop_duplicates()
df_four
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
duplicateRows = df_three[df_three.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [movie_id, title, mpaa_rating, budget, gross, release_date, genre, runtime, rating, rating_count]
# Index: []

# %%
duplicateRows_title = df_three[df_three.duplicated(['title'])]
duplicateRows_title
# Out:
#      movie_id                         title mpaa_rating       budget  \
# 249       250             Jurassic Park III       PG-13   93000000.0
# 501       502  Teenage Mutant Ninja Turtles       PG-13  125000000.0
# 504       505                      Godzilla       PG-13  160000000.0
# 565       566          Beauty and the Beast          PG  160000000.0
# 609       610                       Aladdin          PG  183000000.0
# 613       614                 The Lion King          PG  250000000.0
#
#             gross release_date      genre  runtime  rating  rating_count
# 249  3.687808e+08   2001-07-18  Adventure     92.0     5.9      280110.0
# 501  4.772000e+08   2014-08-07     Action    101.0     5.8      194073.0
# 504  5.290761e+08   2014-05-14   Thriller    123.0     6.4      359438.0
# 565  1.262886e+09   2017-03-16      Drama    129.0     6.9           NaN
# 609  1.049000e+09   2019-05-08    Fantasy    128.0     6.9           NaN
# ...

# %%
dropped_df = df_three.drop(duplicateRows_title)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-ef1217f00dd7> in <module>
# ----> 1 dropped_df = df_three.drop(duplicateRows_title)
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
# Convert Budget into integer type (use astype() method)
df_four = df_three.astype({'budget':'int'})

df_four
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
df_four.dtypes
# Out:
# movie_id          int64
# title            object
# mpaa_rating      object
# budget            int32
# gross           float64
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# dtype: object

# %%
# convert "gross" to integer

df_five = df_four.astype({'gross':'int'})
df_five
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
df_five.dtypes
# Out:
# movie_id          int64
# title            object
# mpaa_rating      object
# budget            int32
# gross             int32
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# dtype: object

# %%
# Convert Release Date into date type (use to_datetime method)

# df_six = df_five.to_datetime({"release_date" : ""})

df_five["release_date"] = pd.to_datetime(df_five["release_date"], format = "%Y/%m/%d")

# %%
df_five
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
df_five.dtypes
# Out:
# movie_id                 int64
# title                   object
# mpaa_rating             object
# budget                   int32
# gross                    int32
# release_date    datetime64[ns]
# genre                   object
# runtime                float64
# rating                 float64
# rating_count           float64
# dtype: object

# %%
# show the movies with more than 7 in Rating & greater than 50 million Gross

# %%
# show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating

# %%
# count of Animation movies with more than 7 in Rating (use the shape() function)

# %%
# show the list of top 5 movies based on Budget

# %%
# show the top 5 Comedy movies by Rating

# %%
# top 5 movie names by Rating

# %%
# top 3 high Gross Romance movies released after 1999, not included (typecast it to datetime)

# %%
# how many Genres are present in the dataframe? (use the function value_counts() which applies to Series, not Dataframe)

# %%
# top 5 expensive movies released after 1999, not included (measured by Budget)

# %%
# most & least frequent MPAA Rating in the dataset in terms of occurances

# %%
# most and least expensive Genre (take an average of all Budget measures grouped by Genre - use groupBy() method)

# %%
# which Genre is favored the most by the people?
