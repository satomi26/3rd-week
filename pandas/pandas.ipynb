# %%
import pandas as pd

# %%
df = pd.read_csv("movies_2.csv", index_col = "MovieID")
df.head(10)
# Out:
#                               Title MPAA Rating      Budget        Gross  \
# MovieID
# 1                Look Who's Talking       PG-13   7500000.0  296000000.0
# 2                Driving Miss Daisy          PG   7500000.0  145793296.0
# 3                    Turner & Hooch          PG  13000000.0   71079915.0
# 4        Born on the Fourth of July           R  14000000.0  161001698.0
# 5                   Field of Dreams          PG  15000000.0   84431625.0
# 6                        Uncle Buck          PG  15000000.0   79258538.0
# 7           When Harry Met Sally...           R  16000000.0   92800000.0
# 8                Dead Poets Society          PG  16400000.0  235860116.0
# 9                        Parenthood       PG-13  20000000.0  126297830.0
# 10                  Lethal Weapon 2           R  25000000.0  227853986.0
#
#         Release Date    Genre  Runtime  Rating  Rating Count  \
# MovieID
# 1         1989-10-12  Romance     93.0     5.9       73638.0
# 2         1989-12-13   Comedy     99.0     7.4       91075.0
# 3         1989-07-28    Crime    100.0     7.2       91415.0
# 4         1989-12-20      War    145.0     7.2       91415.0
# 5         1989-04-21    Drama    107.0     7.5      101702.0
# 6         1989-08-16   Family    100.0     7.0       77659.0
# 7         1989-07-21  Romance     96.0     7.6      180871.0
# 8         1989-06-02    Drama    129.0     8.1      382002.0
# 9         1989-07-31   Comedy    124.0     7.0       41866.0
# 10        1989-07-07   Comedy    114.0     7.2      151737.0
#
#                                                    Summary
# MovieID
# 1        After a single, career-minded woman is left on...
# 2        An old Jewish woman and her African-American c...
# 3        Det. Scott Turner (Tom Hanks) is an uptight, b...
# 4        The biography of Ron Kovic. Paralyzed in the V...
# 5        An Iowa corn farmer, hearing voices, interpret...
# 6        Bachelor and all-round slob Buck babysits his ...
# 7        Harry and Sally have known each other for year...
# 8        English teacher John Keating inspires his stud...
# 9        The Buckmans are a midwestern family all deali...
# 10       Riggs and Murtaugh are on the trail of South A...

# %%
df.tail(10)
# Out:
#                                          Title MPAA Rating       Budget  \
# MovieID
# 607                  Spider-Man: Far from Home       PG-13  160000000.0
# 608                                      Dumbo          PG  170000000.0
# 609                             Captain Marvel       PG-13  175000000.0
# 610                                    Aladdin          PG  183000000.0
# 611             Godzilla: King of the Monsters       PG-13  200000000.0
# 612                                Toy Story 4           G  200000000.0
# 613      Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 614                              The Lion King          PG  250000000.0
# 615                          Avengers: Endgame       PG-13  356000000.0
# 0                                          NaN         NaN          NaN
#
#                 Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# MovieID
# 607      1.131000e+09   2019-06-26     Action    129.0     NaN           NaN
# 608      3.530000e+08   2019-03-11  Adventure    112.0     NaN           NaN
# 609      1.128000e+09   2019-02-27     Action    124.0     NaN           NaN
# 610      1.049000e+09   2019-05-08    Fantasy    128.0     NaN           NaN
# 611      3.859000e+08   2019-05-13  Adventure    132.0     NaN           NaN
# 612      1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 613      7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 614      1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 615      2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 0                 NaN          NaN        NaN      NaN     NaN           NaN
#
#         Summary
# MovieID
# 607         NaN
# 608         NaN
# 609         NaN
# 610         NaN
# 611         NaN
# 612         NaN
# 613         NaN
# 614         NaN
# 615         NaN
# 0           NaN

# %%
# the number of rows and columns present in the data set 
df.shape
# Out:
# (616, 10)

# %%
# columns present in the data set, along with the data type
df.info
# Out:
# <bound method DataFrame.info of                                          Title MPAA Rating       Budget  \
# MovieID
# 1                           Look Who's Talking       PG-13    7500000.0
# 2                           Driving Miss Daisy          PG    7500000.0
# 3                               Turner & Hooch          PG   13000000.0
# 4                   Born on the Fourth of July           R   14000000.0
# 5                              Field of Dreams          PG   15000000.0
# ...                                        ...         ...          ...
# 612                                Toy Story 4           G  200000000.0
# 613      Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 614                              The Lion King          PG  250000000.0
# 615                          Avengers: Endgame       PG-13  356000000.0
# 0                                          NaN         NaN          NaN
#
#                 Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# MovieID
# 1        2.960000e+08   1989-10-12    Romance     93.0     5.9       73638.0
# 2        1.457933e+08   1989-12-13     Comedy     99.0     7.4       91075.0
# 3        7.107992e+07   1989-07-28      Crime    100.0     7.2       91415.0
# 4        1.610017e+08   1989-12-20        War    145.0     7.2       91415.0
# 5        8.443162e+07   1989-04-21      Drama    107.0     7.5      101702.0
# ...               ...          ...        ...      ...     ...           ...
# 612      1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 613      7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 614      1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 615      2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 0                 NaN          NaN        NaN      NaN     NaN           NaN
#
#                                                    Summary
# MovieID
# 1        After a single, career-minded woman is left on...
# 2        An old Jewish woman and her African-American c...
# 3        Det. Scott Turner (Tom Hanks) is an uptight, b...
# 4        The biography of Ron Kovic. Paralyzed in the V...
# 5        An Iowa corn farmer, hearing voices, interpret...
# ...                                                    ...
# 612                                                    NaN
# 613                                                    NaN
# 614                                                    NaN
# 615                                                    NaN
# 0                                                      NaN
#
# [616 rows x 10 columns]>

# %%
df.dtypes
# Out:
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Title             1
# MPAA Rating       1
# Budget            1
# Gross             1
# Release Date      1
# Genre             1
# Runtime           1
# Rating          108
# Rating Count    108
# Summary         120
# dtype: int64

# %%
df_one = df.drop(["Summary"], axis = 1)

# %%
df_two = df_one.rename(index_col = {"MovieID": "movie_id"}, columns={"MovieID": "movie_id", "Title": "title","MPAA Rating": "mpaa_rating","Budget": "budget", "Gross": "gross", "Release Date": "release_date","Genre": "genre","Runtime": "runtime", "Rating":"rating", "Rating Count":"rating_count"})
df_two
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-cb1a6722933a> in <module>
# ----> 1 df_two = df_one.rename(index_col = {"MovieID": "movie_id"}, columns={"MovieID": "movie_id", "Title": "title","MPAA Rating": "mpaa_rating","Budget": "budget", "Gross": "gross", "Release Date": "release_date","Genre": "genre","Runtime": "runtime", "Rating":"rating", "Rating Count":"rating_count"})
#       2 df_two
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     225         @wraps(func)
#     226         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 227             return func(*args, **kwargs)
#     228
#     229         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# TypeError: rename() got an unexpected keyword argument 'index_col'

# %%
df_three = df_two[:-1]
df_three
# Out:
#                                          title mpaa_rating       budget  \
# MovieID
# 1                           Look Who's Talking       PG-13    7500000.0
# 2                           Driving Miss Daisy          PG    7500000.0
# 3                               Turner & Hooch          PG   13000000.0
# 4                   Born on the Fourth of July           R   14000000.0
# 5                              Field of Dreams          PG   15000000.0
# ...                                        ...         ...          ...
# 611             Godzilla: King of the Monsters       PG-13  200000000.0
# 612                                Toy Story 4           G  200000000.0
# 613      Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 614                              The Lion King          PG  250000000.0
# 615                          Avengers: Endgame       PG-13  356000000.0
#
#                 gross release_date      genre  runtime  rating  rating_count
# MovieID
# 1        2.960000e+08   1989-10-12    Romance     93.0     5.9       73638.0
# 2        1.457933e+08   1989-12-13     Comedy     99.0     7.4       91075.0
# 3        7.107992e+07   1989-07-28      Crime    100.0     7.2       91415.0
# 4        1.610017e+08   1989-12-20        War    145.0     7.2       91415.0
# 5        8.443162e+07   1989-04-21      Drama    107.0     7.5      101702.0
# ...               ...          ...        ...      ...     ...           ...
# 611      3.859000e+08   2019-05-13  Adventure    132.0     NaN           NaN
# 612      1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 613      7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 614      1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 615      2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
#
# [615 rows x 9 columns]

# %%
df_three.isna().sum()
# Out:
# title             0
# mpaa_rating       0
# budget            0
# gross             0
# release_date      0
# genre             0
# runtime           0
# rating          107
# rating_count    107
# dtype: int64

# %%
# we have missing data in column "rating" and "rating count"
# find the mean and median from "rating" and "rating count"

df_mean = df_three.mean()
df_mean
# Out:
# budget          9.491710e+07
# gross           4.453221e+08
# runtime         1.186423e+02
# rating          6.917323e+00
# rating_count    3.392521e+05
# dtype: float64

# %%
# use fillna() method to replace the missing values of Rating with their median

filled_df = df_three["rating"].fillna(value = 6.9, inplace=True)
print(filled_df)
# Out:
# None
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df_three.shape
# Out:
# (615, 9)

# %%
df_four = df_three.drop_duplicates()
df_four
# Out:
#                                          title mpaa_rating       budget  \
# MovieID
# 1                           Look Who's Talking       PG-13    7500000.0
# 2                           Driving Miss Daisy          PG    7500000.0
# 3                               Turner & Hooch          PG   13000000.0
# 4                   Born on the Fourth of July           R   14000000.0
# 5                              Field of Dreams          PG   15000000.0
# ...                                        ...         ...          ...
# 611             Godzilla: King of the Monsters       PG-13  200000000.0
# 612                                Toy Story 4           G  200000000.0
# 613      Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 614                              The Lion King          PG  250000000.0
# 615                          Avengers: Endgame       PG-13  356000000.0
#
#                 gross release_date      genre  runtime  rating  rating_count
# MovieID
# 1        2.960000e+08   1989-10-12    Romance     93.0     5.9       73638.0
# 2        1.457933e+08   1989-12-13     Comedy     99.0     7.4       91075.0
# 3        7.107992e+07   1989-07-28      Crime    100.0     7.2       91415.0
# 4        1.610017e+08   1989-12-20        War    145.0     7.2       91415.0
# 5        8.443162e+07   1989-04-21      Drama    107.0     7.5      101702.0
# ...               ...          ...        ...      ...     ...           ...
# 611      3.859000e+08   2019-05-13  Adventure    132.0     6.9           NaN
# 612      1.062000e+09   2019-06-11  Animation    100.0     6.9           NaN
# 613      7.594000e+08   2019-07-13   Thriller    136.0     6.9           NaN
# 614      1.632000e+09   2019-07-09      Drama    118.0     6.9           NaN
# 615      2.796000e+09   2019-04-22     Action    181.0     6.9           NaN
#
# [615 rows x 9 columns]

# %%
duplicateRows = df_three[df_three.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [title, mpaa_rating, budget, gross, release_date, genre, runtime, rating, rating_count]
# Index: []

# %%
duplicateRows_title = df_three[df_three.duplicated(['title'])]
duplicateRows_title
# Out:
#                                 title mpaa_rating       budget         gross  \
# MovieID
# 250                 Jurassic Park III       PG-13   93000000.0  3.687808e+08
# 502      Teenage Mutant Ninja Turtles       PG-13  125000000.0  4.772000e+08
# 505                          Godzilla       PG-13  160000000.0  5.290761e+08
# 566              Beauty and the Beast          PG  160000000.0  1.262886e+09
# 610                           Aladdin          PG  183000000.0  1.049000e+09
# 614                     The Lion King          PG  250000000.0  1.632000e+09
#
#         release_date      genre  runtime  rating  rating_count
# MovieID
# 250       2001-07-18  Adventure     92.0     5.9      280110.0
# 502       2014-08-07     Action    101.0     5.8      194073.0
# 505       2014-05-14   Thriller    123.0     6.4      359438.0
# 566       2017-03-16      Drama    129.0     6.9           NaN
# 610       2019-05-08    Fantasy    128.0     6.9           NaN
# 614       2019-07-09      Drama    118.0     6.9           NaN

# %%
dropped_df = df_three.drop(duplicateRows_title)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-184-ef1217f00dd7> in <module>
# ----> 1 dropped_df = df_three.drop(duplicateRows_title)
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['title' 'mpaa_rating' 'budget' 'gross' 'release_date' 'genre' 'runtime'\n 'rating' 'rating_count'] not found in axis"

# %%
# Convert Budget into integer type (use astype() method)
df_four = df_three.astype({'budget':'int'})

df_four
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
#             gross release_date      genre  runtime  rating  rating_count
# 0    2.960000e+08   1989-10-12    Romance     93.0     5.9       73638.0
# 1    1.457933e+08   1989-12-13     Comedy     99.0     7.4       91075.0
# 2    7.107992e+07   1989-07-28      Crime    100.0     7.2       91415.0
# 3    1.610017e+08   1989-12-20        War    145.0     7.2       91415.0
# 4    8.443162e+07   1989-04-21      Drama    107.0     7.5      101702.0
# ..            ...          ...        ...      ...     ...           ...
# 610  3.859000e+08   2019-05-13  Adventure    132.0     6.9           NaN
# 611  1.062000e+09   2019-06-11  Animation    100.0     6.9           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     6.9           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     6.9           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     6.9           NaN
#
# [615 rows x 10 columns]

# %%
df_four.dtypes
# Out:
# movie_id          int64
# title            object
# mpaa_rating      object
# budget            int32
# gross           float64
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# dtype: object

# %%
# convert "gross" to integer

df_five = df_four.astype({'gross':'int'})
df_five
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
#           gross release_date      genre  runtime  rating  rating_count
# 0     296000000   1989-10-12    Romance     93.0     5.9       73638.0
# 1     145793296   1989-12-13     Comedy     99.0     7.4       91075.0
# 2      71079915   1989-07-28      Crime    100.0     7.2       91415.0
# 3     161001698   1989-12-20        War    145.0     7.2       91415.0
# 4      84431625   1989-04-21      Drama    107.0     7.5      101702.0
# ..          ...          ...        ...      ...     ...           ...
# 610   385900000   2019-05-13  Adventure    132.0     6.9           NaN
# 611  1062000000   2019-06-11  Animation    100.0     6.9           NaN
# 612   759400000   2019-07-13   Thriller    136.0     6.9           NaN
# 613  1632000000   2019-07-09      Drama    118.0     6.9           NaN
# 614 -2147483648   2019-04-22     Action    181.0     6.9           NaN
#
# [615 rows x 10 columns]

# %%
df_five.dtypes
# Out:
# movie_id          int64
# title            object
# mpaa_rating      object
# budget            int32
# gross             int32
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# dtype: object

# %%
# Convert Release Date into date type (use to_datetime method)

# df_six = df_five.to_datetime({"release_date" : ""})

df_five["release_date"] = pd.to_datetime(df_five["release_date"], format = "%Y/%m/%d")

# %%
cleaned_df = df_five
cleaned_df
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
#           gross release_date      genre  runtime  rating  rating_count
# 0     296000000   1989-10-12    Romance     93.0     5.9       73638.0
# 1     145793296   1989-12-13     Comedy     99.0     7.4       91075.0
# 2      71079915   1989-07-28      Crime    100.0     7.2       91415.0
# 3     161001698   1989-12-20        War    145.0     7.2       91415.0
# 4      84431625   1989-04-21      Drama    107.0     7.5      101702.0
# ..          ...          ...        ...      ...     ...           ...
# 610   385900000   2019-05-13  Adventure    132.0     6.9           NaN
# 611  1062000000   2019-06-11  Animation    100.0     6.9           NaN
# 612   759400000   2019-07-13   Thriller    136.0     6.9           NaN
# 613  1632000000   2019-07-09      Drama    118.0     6.9           NaN
# 614 -2147483648   2019-04-22     Action    181.0     6.9           NaN
#
# [615 rows x 10 columns]

# %%
cleaned_df.dtypes
# Out:
# movie_id                 int64
# title                   object
# mpaa_rating             object
# budget                   int32
# gross                    int32
# release_date    datetime64[ns]
# genre                   object
# runtime                float64
# rating                 float64
# rating_count           float64
# dtype: object

# %%
# show the movies with more than 7 in Rating & greater than 50 million Gross
cleaned_df[(cleaned_df["rating"] > 7) & (cleaned_df["gross"] > 50000000)]
# Out:
#      movie_id                                title mpaa_rating     budget  \
# 1           2                   Driving Miss Daisy          PG    7500000
# 2           3                       Turner & Hooch          PG   13000000
# 3           4           Born on the Fourth of July           R   14000000
# 4           5                      Field of Dreams          PG   15000000
# 6           7              When Harry Met Sally...           R   16000000
# ..        ...                                  ...         ...        ...
# 505       506                           Big Hero 6          PG  165000000
# 506       507                         Interstellar       PG-13  165000000
# 507       508  Captain America: The Winter Soldier       PG-13  170000000
# 508       509       Dawn of the Planet of the Apes       PG-13  170000000
# 509       510              Guardians of the Galaxy       PG-13  170000000
#
#          gross release_date            genre  runtime  rating  rating_count
# 1    145793296   1989-12-13           Comedy     99.0     7.4       91075.0
# 2     71079915   1989-07-28            Crime    100.0     7.2       91415.0
# 3    161001698   1989-12-20              War    145.0     7.2       91415.0
# 4     84431625   1989-04-21            Drama    107.0     7.5      101702.0
# 6     92800000   1989-07-21          Romance     96.0     7.6      180871.0
# ..         ...          ...              ...      ...     ...           ...
# 505  652105443   2014-10-24        Animation    102.0     7.8      380953.0
# 506  675120017   2014-11-05  Science Fiction    169.0     8.6     1343549.0
# 507  714766572   2014-03-20           Action    136.0     7.7      685903.0
# 508  710644566   2014-06-26  Science Fiction    130.0     7.6      395425.0
# 509  773328629   2014-07-30           Action    121.0     8.0      978222.0
#
# [223 rows x 10 columns]

# %%
# show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating

selected_movie = cleaned_df[(cleaned_df["rating"] > 7) & (cleaned_df["gross"] > 50000000) & (cleaned_df["mpaa_rating"] == "PG")]
selected_movie
# Out:
#      movie_id                                     title mpaa_rating  \
# 1           2                        Driving Miss Daisy          PG
# 2           3                            Turner & Hooch          PG
# 4           5                           Field of Dreams          PG
# 7           8                        Dead Poets Society          PG
# 13         14                                    Batman          PG
# 15         16                        The Little Mermaid          PG
# 16         17                Back to the Future Part II          PG
# 19         20                           Steel Magnolias          PG
# 24         25                                Home Alone          PG
# 32         33                  The Hunt for Red October          PG
# 34         35               Back to the Future Part III          PG
# 45         46           Teenage Mutant Ninja Turtles II          PG
# 46         47                      Beauty and the Beast          PG
# 49         50    Star Trek VI: The Undiscovered Country          PG
# 72         73                     A League of Their Own          PG
# 80         81                             Groundhog Day          PG
# 106       107                    Star Trek: Generations          PG
# 126       127                        Mr. Holland's Opus          PG
# 130       131                                 Apollo 13          PG
# 174       175                                   Contact          PG
# 185       186                           The Truman Show          PG
# 188       189                       The Prince of Egypt          PG
# 215       216                                    Tarzan          PG
# 220       221                       Remember the Titans          PG
# 241       242                                     Shrek          PG
# 255       256     Harry Potter and the Sorcerer's Stone          PG
# 261       262                                   Ice Age          PG
# 270       271   Harry Potter and the Chamber of Secrets          PG
# 304       305                           The Incredibles          PG
# 309       310  Harry Potter and the Prisoner of Azkaban          PG
# 311       312                                   Shrek 2          PG
# 385       386                             Kung Fu Panda          PG
# 410       411                        Monsters vs Aliens          PG
# 411       412                                        Up          PG
# 415       416    Harry Potter and the Half-Blood Prince          PG
# 420       421                             Despicable Me          PG
# 425       426                                  Megamind          PG
# 428       429                  How to Train Your Dragon          PG
# 435       436                                   Tangled          PG
# 447       448          Puss in Boots: The Three Diablos          PG
# 451       452                           Kung Fu Panda 2          PG
# 461       462                        Hotel Transylvania          PG
# 466       467                            Wreck-It Ralph          PG
# 468       469                                     Brave          PG
# 480       481                           Despicable Me 2          PG
# 484       485                                The Croods          PG
# 485       486                                    Frozen          PG
# 498       499                            The Lego Movie          PG
# 503       504                How to Train Your Dragon 2          PG
# 505       506                                Big Hero 6          PG
#
#         budget       gross release_date            genre  runtime  rating  \
# 1      7500000   145793296   1989-12-13           Comedy     99.0     7.4
# 2     13000000    71079915   1989-07-28            Crime    100.0     7.2
# 4     15000000    84431625   1989-04-21            Drama    107.0     7.5
# 7     16400000   235860116   1989-06-02            Drama    129.0     8.1
# 13    35000000   411348924   1989-06-23           Action    126.0     7.5
# 15    40000000   222300000   1989-11-17        Animation     83.0     7.6
# 16    40000000   332000000   1989-11-20  Science Fiction    108.0     7.8
# 19    15000000    95904091   1989-11-15            Drama    119.0     7.3
# 24    18000000   476684675   1990-11-09           Family    103.0     7.6
# 32    30000000   199200000   1990-03-02         Thriller    134.0     7.6
# 34    40000000   244527583   1990-05-25           Family    118.0     7.4
# 45    25000000    78600000   1991-03-22           Action     88.0     8.0
# 46    25000000   377350553   1991-11-13        Animation     84.0     8.0
# 49    27000000    96900000   1991-12-05  Science Fiction    113.0     7.2
# 72    40000000   107458785   1992-07-01           Comedy    128.0     7.2
# 80    14600000    70906973   1993-02-11           Comedy    101.0     8.0
# 106   38000000   120000000   1994-11-17  Science Fiction    118.0     8.5
# 126   31000000   106269971   1995-12-29           Family    137.0     7.3
# 130   52000000   355237933   1995-06-30            Drama    140.0     7.6
# 174   90000000   171120329   1997-07-11  Science Fiction    150.0     7.4
# 185   60000000   264118201   1998-06-04           Comedy    103.0     8.1
# 188   70000000   218613188   1998-12-15        Animation     99.0     7.1
# 215  150000000   448000000   1999-06-18        Animation     88.0     7.3
# 220   30000000   136706683   2000-09-29            Drama    113.0     7.8
# 241   60000000   484409218   2001-05-16        Animation     90.0     7.8
# 255  125000000   975100000   2001-11-04          Fantasy    152.0     7.6
# 261   59000000   383257136   2002-03-10        Animation     81.0     7.5
# 270  100000000   876688482   2002-11-13          Fantasy    161.0     7.4
# 304   92000000   631442092   2004-11-05        Animation    115.0     8.0
# 309  130000000   789804554   2004-05-31          Fantasy    141.0     7.9
# 311  150000000   919838758   2004-05-19        Animation     93.0     7.2
# 385  130000000   631744560   2008-06-04        Animation     90.0     7.5
# 410  175000000   381509870   2009-03-19        Animation     94.0     7.7
# 411  175000000   735099082   2009-05-13        Animation     96.0     8.2
# 415  250000000   933959197   2009-07-07          Fantasy    153.0     7.6
# 420   69000000   543513985   2010-07-08        Animation     95.0     7.6
# 425  130000000   321887208   2010-10-28        Animation     95.0     7.2
# 428  165000000   494878759   2010-03-05        Animation     98.0     8.1
# 435  260000000   591794936   2010-11-24        Animation    100.0     7.7
# 447  130000000   555000000   2011-12-08        Animation    130.0     7.8
# 451  150000000   665692281   2011-05-25        Animation     91.0     7.2
# 461   85000000   358375603   2012-09-20        Animation     91.0     7.1
# 466  165000000   471222889   2012-11-01        Animation    108.0     7.7
# 468  185000000   538983207   2012-06-21        Animation     93.0     7.1
# 480   76000000   970761885   2013-06-25        Animation     98.0     7.4
# 484  135000000   585178928   2013-03-20        Animation     98.0     7.2
# 485  150000000  1274219009   2013-11-27        Animation    102.0     7.5
# 498   60000000   469160692   2014-02-06        Animation    100.0     7.8
# 503  145000000   609123048   2014-06-12        Animation    102.0     7.8
# 505  165000000   652105443   2014-10-24        Animation    102.0     7.8
#
#      rating_count
# 1         91075.0
# 2         91415.0
# 4        101702.0
# 7        382002.0
# 13       319517.0
# 15       219221.0
# 16       438940.0
# 19        43037.0
# 24       414472.0
# 32       167212.0
# 34       369652.0
# 45       397467.0
# 46       397467.0
# 49        66086.0
# 72        85932.0
# 80       549538.0
# 106      869127.0
# 126       33906.0
# 130      250975.0
# 174      239569.0
# 185      859224.0
# 188      110340.0
# 215      187724.0
# 220      186997.0
# 241      574978.0
# 255      583224.0
# 261      411963.0
# 270      505027.0
# 304      617102.0
# 309      501648.0
# 311      391295.0
# 385      390478.0
# 410      374981.0
# 411      867393.0
# 415      429384.0
# 420      473121.0
# 425      212563.0
# 428      624128.0
# 435      374981.0
# 447      727724.0
# 451      234612.0
# 461      208916.0
# 466      354202.0
# 468      346490.0
# 480      350582.0
# 484      180043.0
# 485      527284.0
# 498      309295.0
# 503      285394.0
# 505      380953.0

# %%
selected_movie.shape
# Out:
# (50, 10)

# %%
# count of Animation movies with more than 7 in Rating (use the shape() function)

animation_with_7 = cleaned_df[(cleaned_df["genre"] == "Animation") & (cleaned_df["rating"] > 7) ]
animation_with_7
# Out:
#      movie_id                             title mpaa_rating     budget  \
# 15         16                The Little Mermaid          PG   40000000
# 46         47              Beauty and the Beast          PG   25000000
# 65         66                           Aladdin           G   28000000
# 107       108                     The Lion King           G   45000000
# 123       124                         Toy Story           G   30000000
# 171       172                          Hercules           G   85000000
# 188       189               The Prince of Egypt          PG   70000000
# 191       192                             Mulan           G   90000000
# 194       195                      A Bug's Life           G  120000000
# 211       212                       Toy Story 2           G   90000000
# 215       216                            Tarzan          PG  150000000
# 241       242                             Shrek          PG   60000000
# 261       262                           Ice Age          PG   59000000
# 286       287                      Finding Nemo           G   94000000
# 304       305                   The Incredibles          PG   92000000
# 311       312                           Shrek 2          PG  150000000
# 349       350                              Cars           G  120000000
# 369       370                       Ratatouille           G  150000000
# 385       386                     Kung Fu Panda          PG  130000000
# 391       392                            WALL-E           G  180000000
# 410       411                Monsters vs Aliens          PG  175000000
# 411       412                                Up          PG  175000000
# 420       421                     Despicable Me          PG   69000000
# 425       426                          Megamind          PG  130000000
# 428       429          How to Train Your Dragon          PG  165000000
# 433       434                       Toy Story 3           G  200000000
# 435       436                           Tangled          PG  260000000
# 447       448  Puss in Boots: The Three Diablos          PG  130000000
# 451       452                   Kung Fu Panda 2          PG  150000000
# 461       462                Hotel Transylvania          PG   85000000
# 466       467                    Wreck-It Ralph          PG  165000000
# 468       469                             Brave          PG  185000000
# 480       481                   Despicable Me 2          PG   76000000
# 484       485                        The Croods          PG  135000000
# 485       486                            Frozen          PG  150000000
# 492       493               Monsters University           G  200000000
# 498       499                    The Lego Movie          PG   60000000
# 503       504        How to Train Your Dragon 2          PG  145000000
# 505       506                        Big Hero 6          PG  165000000
#
#           gross release_date      genre  runtime  rating  rating_count
# 15    222300000   1989-11-17  Animation     83.0     7.6      219221.0
# 46    377350553   1991-11-13  Animation     84.0     8.0      397467.0
# 65    504050219   1992-11-25  Animation     90.0     8.0      336384.0
# 107   788241776   1994-06-23  Animation     89.0     8.5      869127.0
# 123   373554033   1995-10-30  Animation     81.0     8.3      820625.0
# 171   252712101   1997-06-26  Animation     93.0     7.3      188044.0
# 188   218613188   1998-12-15  Animation     99.0     7.1      110340.0
# 191   304320254   1998-06-18  Animation     88.0     7.6      229669.0
# 194   363258859   1998-11-25  Animation     95.0     7.2      251436.0
# 211   497366869   1999-10-30  Animation     92.0     7.9      489299.0
# 215   448000000   1999-06-18  Animation     88.0     7.3      187724.0
# 241   484409218   2001-05-16  Animation     90.0     7.8      574978.0
# 261   383257136   2002-03-10  Animation     81.0     7.5      411963.0
# 286   940335536   2003-05-30  Animation    100.0     8.1      887773.0
# 304   631442092   2004-11-05  Animation    115.0     8.0      617102.0
# 311   919838758   2004-05-19  Animation     93.0     7.2      391295.0
# 349   461983149   2006-06-08  Animation    117.0     7.1      338715.0
# 369   623722818   2007-06-22  Animation    111.0     8.0      594171.0
# 385   631744560   2008-06-04  Animation     90.0     7.5      390478.0
# 391   533300000   2008-06-23  Animation     97.0     7.6      429384.0
# 410   381509870   2009-03-19  Animation     94.0     7.7      374981.0
# 411   735099082   2009-05-13  Animation     96.0     8.2      867393.0
# 420   543513985   2010-07-08  Animation     95.0     7.6      473121.0
# 425   321887208   2010-10-28  Animation     95.0     7.2      212563.0
# 428   494878759   2010-03-05  Animation     98.0     8.1      624128.0
# 433  1066969703   2010-06-16  Animation    103.0     8.3      705408.0
# 435   591794936   2010-11-24  Animation    100.0     7.7      374981.0
# 447   555000000   2011-12-08  Animation    130.0     7.8      727724.0
# 451   665692281   2011-05-25  Animation     91.0     7.2      234612.0
# 461   358375603   2012-09-20  Animation     91.0     7.1      208916.0
# 466   471222889   2012-11-01  Animation    108.0     7.7      354202.0
# 468   538983207   2012-06-21  Animation     93.0     7.1      346490.0
# 480   970761885   2013-06-25  Animation     98.0     7.4      350582.0
# 484   585178928   2013-03-20  Animation     98.0     7.2      180043.0
# 485  1274219009   2013-11-27  Animation    102.0     7.5      527284.0
# 492   743559607   2013-06-20  Animation    104.0     7.3      299133.0
# 498   469160692   2014-02-06  Animation    100.0     7.8      309295.0
# 503   609123048   2014-06-12  Animation    102.0     7.8      285394.0
# 505   652105443   2014-10-24  Animation    102.0     7.8      380953.0

# %%
animation_with_7.shape
# Out:
# (39, 10)

# %%
# show the list of top 5 movies based on Budget

movies_sorted_topfive = cleaned_df.sort_values(by=["budget"], ascending = False )
movies_sorted_topfive.head()
# Out:
#      movie_id                                        title mpaa_rating  \
# 594       595                       Avengers: Infinity War       PG-13
# 454       455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614       615                            Avengers: Endgame       PG-13
# 574       575                     Star Wars: The Last Jedi       PG-13
# 375       376     Pirates of the Caribbean: At World's End       PG-13
#
#         budget       gross release_date            genre  runtime  rating  \
# 594  400000000  2048000000   2018-04-23           Action    149.0     6.9
# 454  380000000  1045713802   2011-05-14           Action    136.0     6.6
# 614  356000000 -2147483648   2019-04-22           Action    181.0     6.9
# 574  317000000  1333000000   2019-12-09  Science Fiction    152.0     6.9
# 375  300000000   961000000   2007-05-19        Adventure    169.0     7.1
#
#      rating_count
# 594           NaN
# 454      455211.0
# 614           NaN
# 574           NaN
# 375      565402.0

# %%
# show the top 5 Comedy movies by Rating

comedy_movie = cleaned_df[(cleaned_df["genre"] == "Comedy")  ]
comedy_movie
# Out:
#      movie_id                          title mpaa_rating     budget  \
# 1           2             Driving Miss Daisy          PG    7500000
# 8           9                     Parenthood       PG-13   20000000
# 9          10                Lethal Weapon 2           R   25000000
# 10         11           The War of the Roses           R   26000000
# 14         15                Ghostbusters II          PG   37000000
# ..        ...                            ...         ...        ...
# 516       517                Pitch Perfect 2       PG-13   29000000
# 537       538                       Deadpool           R   58000000
# 582       583                     Deadpool 2           R  110000000
# 597       598                     The Upside       PG-13   37500000
# 601       602  Once Upon a Time in Hollywood           R   96000000
#
#          gross release_date   genre  runtime  rating  rating_count
# 1    145793296   1989-12-13  Comedy     99.0     7.4       91075.0
# 8    126297830   1989-07-31  Comedy    124.0     7.0       41866.0
# 9    227853986   1989-07-07  Comedy    114.0     7.2      151737.0
# 10   160200000   1989-12-08  Comedy    116.0     6.8       45248.0
# 14   215394738   1989-06-15  Comedy    108.0     6.6      171196.0
# ..         ...          ...     ...      ...     ...           ...
# 516  287506194   2015-05-07  Comedy    115.0     6.9           NaN
# 537  783112979   2016-02-09  Comedy    108.0     6.9           NaN
# 582  785000000   2018-05-10  Comedy    119.0     6.9           NaN
# 597  122800000   2019-01-11  Comedy    126.0     6.9           NaN
# 601  345900000   2019-05-21  Comedy    161.0     6.9           NaN
#
# [99 rows x 10 columns]

# %%
comedy_movie.sort_values(by = ["rating"], ascending = False)
print("top 5 comedy movies by rating are: ")
comedy_movie.head()
# Out:
# top 5 comedy movies by rating are:
#     movie_id                 title mpaa_rating    budget      gross  \
# 1          2    Driving Miss Daisy          PG   7500000  145793296
# 8          9            Parenthood       PG-13  20000000  126297830
# 9         10       Lethal Weapon 2           R  25000000  227853986
# 10        11  The War of the Roses           R  26000000  160200000
# 14        15       Ghostbusters II          PG  37000000  215394738
#
#    release_date   genre  runtime  rating  rating_count
# 1    1989-12-13  Comedy     99.0     7.4       91075.0
# 8    1989-07-31  Comedy    124.0     7.0       41866.0
# 9    1989-07-07  Comedy    114.0     7.2      151737.0
# 10   1989-12-08  Comedy    116.0     6.8       45248.0
# 14   1989-06-15  Comedy    108.0     6.6      171196.0

# %%
# top 5 movie names by Rating

top_five_movies = cleaned_df.sort_values(by = ["rating"], ascending = False)
print("top 5 movie names are: ")
top_five_movies["title"].head()
# Out:
# top 5 movie names are:
# 393                                  The Dark Knight
# 83                                  Schindler's List
# 287    The Lord of the Rings: The Return of the King
# 99                                      Pulp Fiction
# 98                                 Jurassic Park III
# Name: title, dtype: object

# %%
# top 3 high Gross Romance movies released after 1999, not included (typecast it to datetime)

romance_after_millenium = cleaned_df[(cleaned_df["genre"] == "Romance")]
romance_after_millenium.sort_values(by=["gross"], ascending = False )
# Out:
#      movie_id                                      title mpaa_rating  \
# 177       178                                    Titanic       PG-13
# 464       465  The Twilight Saga: Breaking Dawn - Part 2       PG-13
# 442       443  The Twilight Saga: Breaking Dawn - Part 1       PG-13
# 401       402                The Twilight Saga: New Moon       PG-13
# 419       420                 The Twilight Saga: Eclipse       PG-13
# 379       380                                 Mamma Mia!       PG-13
# 22         23                               Pretty Woman           R
# 577       578                             A Star is Born           R
# 378       379                                   Twilight       PG-13
# 178       179               There's Something About Mary           R
# 203       204                               Notting Hill       PG-13
# 103       104                                   The Mask       PG-13
# 400       401                               The Proposal       PG-13
# 207       208                              Runaway Bride          PG
# 0           1                         Look Who's Talking       PG-13
# 186       187                            You've Got Mail          PG
# 576       577                          Crazy Rich Asians       PG-13
# 82         83                       Sleepless in Seattle          PG
# 217       218             Crouching Tiger, Hidden Dragon       PG-13
# 339       340                               The Break-Up       PG-13
# 119       120                    While You Were Sleeping          PG
# 258       259                         Sweet Home Alabama       PG-13
# 239       240                       The Princess Diaries           G
# 6           7                    When Harry Met Sally...           R
# 43         44                        Father of the Bride          PG
# 51         52                        The Prince of Tides           R
# 71         72                                  Boomerang           R
# 59         60                            The Crying Game           R
#
#         budget       gross release_date    genre  runtime  rating  \
# 177  200000000  1845034188   1997-11-18  Romance    194.0     7.8
# 464  120000000   829000000   2012-11-13  Romance    115.0     5.5
# 442  110000000   712171856   2011-03-15  Romance    117.0     4.9
# 401   50000000   709827462   2009-03-15  Romance    130.0     4.7
# 419   68000000   698491347   2010-06-23  Romance    124.0     5.0
# 379   52000000   609841637   2008-07-03  Romance    108.0     6.4
# 22    14000000   463000000   1990-03-23  Romance    119.0     7.0
# 577   36000000   435000000   2018-08-31  Romance    135.0     6.9
# 378   37000000   392616625   2008-11-20  Romance    122.0     5.2
# 178   23000000   369884651   1998-07-15  Romance    119.0     7.1
# 203   42000000   363889678   1999-05-13  Romance    124.0     7.1
# 103   23000000   351583407   1994-07-29  Romance    101.0     6.9
# 400   40000000   317375031   2009-06-01  Romance    108.0     6.7
# 207   70000000   309457509   1999-07-30  Romance    116.0     5.5
# 0      7500000   296000000   1989-10-12  Romance     93.0     5.9
# 186   65000000   250821495   1998-12-17  Romance    119.0     6.6
# 576   30000000   238500000   2018-08-07  Romance    121.0     6.9
# 82    21000000   227799884   1993-06-24  Romance    105.0     6.8
# 217   17000000   213525736   2000-10-01  Romance    120.0     7.8
# 339   52000000   204999686   2006-06-01  Romance    106.0     5.8
# 119   17000000   182057016   1995-04-21  Romance    103.0     6.7
# 258   30000000   180622424   2002-09-26  Romance    108.0     6.2
# 239   37000000   165335153   2001-08-03  Romance    115.0     6.3
# 6     16000000    92800000   1989-07-21  Romance     96.0     7.6
# 43    20000000    89325780   1991-12-20  Romance    105.0     6.5
# 51    30000000    74787599   1991-12-25  Romance    132.0     6.7
# 71    40000000    70100000   1992-06-30  Romance    117.0     5.5
# 59     3705538    62548947   1992-09-02  Romance    112.0     7.2
#
#      rating_count
# 177      978389.0
# 464      218357.0
# 442      211592.0
# 401      252223.0
# 419      215110.0
# 379      198801.0
# 22       266405.0
# 577           NaN
# 378      400765.0
# 178      278096.0
# 203      251006.0
# 103      320839.0
# 400      277605.0
# 207       88557.0
# 0         73638.0
# 186      180707.0
# 576           NaN
# 82       147908.0
# 217      242878.0
# 339      119027.0
# 119       85626.0
# 258       96978.0
# 239      118754.0
# 6        180871.0
# 43        64326.0
# 51        14918.0
# 71        24114.0
# 59        48101.0

# %%
import datetime as dt 
#(cleaned_df['release_date'].dt.year) > 2000 

cleaned_df[(cleaned_df['release_date'] >= '2020-01-01')]
# Out:
# Empty DataFrame
# Columns: [movie_id, title, mpaa_rating, budget, gross, release_date, genre, runtime, rating, rating_count]
# Index: []

# %%
# how many Genres are present in the dataframe? (use the function value_counts() which applies to Series, not Dataframe)
vc = cleaned_df["genre"].value_counts()
vc
# Out:
# Action             110
# Comedy              99
# Animation           87
# Drama               66
# Thriller            41
# Science Fiction     37
# Adventure           30
# Family              29
# Romance             28
# Fantasy             27
# Crime               17
# Horror              14
# Mystery             11
# War                  9
# Western              6
# History              4
# Name: genre, dtype: int64

# %%
# top 5 expensive movies released after 1999, not included (measured by Budget)

movies_topfive = cleaned_df.sort_values(by=["budget"], ascending = False)
movies_topfive = movies_topfive.loc(movies_topfive["release_date"]>= "2000-01-01")
movies_topfive
# filter movies released after 1999?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-312be4da295a> in <module>
#       2
#       3 movies_topfive = cleaned_df.sort_values(by=["budget"], ascending = False)
# ----> 4 movies_topfive = movies_topfive.loc(movies_topfive["release_date"]>= "2000-01-01")
#       5 movies_topfive
#       6 # filter movies released after 1999???????????
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     576
#     577         if axis is not None:
# --> 578             axis = self.obj._get_axis_number(axis)
#     579         new_self.axis = axis
#     580         return new_self
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     396     @classmethod
#     397     def _get_axis_number(cls, axis):
# --> 398         axis = cls._AXIS_ALIASES.get(axis, axis)
#     399         if is_integer(axis):
#     400             if axis in cls._AXIS_NAMES:
#
# c:\Users\satom\anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1796
#    1797     def __hash__(self):
# -> 1798         raise TypeError(
#    1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
# most & least frequent MPAA Rating in the dataset in terms of occurances (発生頻度からいうと)

frequent_mpaa = cleaned_df["mpaa_rating"].value_counts()
print(frequent_mpaa)
print(f"most frequent MPAA Rating is: ", max(frequent_mpaa))
print(f"least frequent MPAA Rating is: ", min(frequent_mpaa))
# Out:
# PG-13    285
# PG       161
# R        142
# G         27
# Name: mpaa_rating, dtype: int64
# most frequent MPAA Rating is:  285
# least frequent MPAA Rating is:  27

# %%
# most and least expensive Genre (take an average of all Budget measures grouped by Genre - use groupBy() method)

average_budget = cleaned_df.groupby("genre").mean()
average_budget.drop(["movie_id"], axis = 1)
# Out:
#                        budget         gross     runtime    rating  \
# genre
# Action           1.441682e+08  5.796084e+08  127.936364  6.985455
# Adventure        1.338333e+08  4.219790e+08  130.266667  6.696667
# Animation        1.158793e+08  5.617414e+08   95.885057  7.110345
# Comedy           4.957727e+07  2.447957e+08  105.919192  6.631313
# Crime            5.658824e+07  2.286779e+08  121.941176  6.876471
# Drama            5.592576e+07  2.989364e+08  126.651515  7.193939
# Family           6.268966e+07  2.920609e+08  104.172414  6.117241
# Fantasy          1.612111e+08  7.926055e+08  143.037037  7.337037
# History          5.550000e+07  2.753178e+08  157.750000  7.625000
# Horror           3.700429e+07  2.724708e+08  116.000000  6.735714
# Mystery          1.035455e+08  3.725879e+08  131.454545  6.827273
# Romance          4.540020e+07  3.841570e+08  117.285714  6.400000
# Science Fiction  1.267838e+08  5.252451e+08  126.567568  7.151351
# Thriller         8.658537e+07  3.963394e+08  121.073171  6.995122
# War              9.075556e+07  3.903759e+08  151.111111  7.355556
# Western          7.983333e+07  3.360111e+08  141.500000  7.333333
#
#                   rating_count
# genre
# Action           477202.539474
# Adventure        399555.076923
# Animation        325150.920635
# Comedy           220524.127660
# Crime            223550.250000
# Drama            291762.785714
# Family           153538.357143
# Fantasy          602313.954545
# History          448652.000000
# Horror           207496.222222
# Mystery          288529.200000
# Romance          205984.269231
# Science Fiction  493352.290323
# Thriller         419500.029412
# War              411161.000000
# Western          451161.600000

# %%
average_budget.sort_values(by = ["budget"])
print(average_budget)
print("This is the least expensive genre: ")
print(average_budget.head(1))
# Out:
#                    movie_id        budget         gross     runtime    rating  \
# genre
# Action           364.136364  1.441682e+08  5.796084e+08  127.936364  6.985455
# Adventure        320.600000  1.338333e+08  4.219790e+08  130.266667  6.696667
# Animation        401.827586  1.158793e+08  5.617414e+08   95.885057  7.110345
# Comedy           246.414141  4.957727e+07  2.447957e+08  105.919192  6.631313
# Crime            196.058824  5.658824e+07  2.286779e+08  121.941176  6.876471
# Drama            262.333333  5.592576e+07  2.989364e+08  126.651515  7.193939
# Family           200.758621  6.268966e+07  2.920609e+08  104.172414  6.117241
# Fantasy          376.740741  1.612111e+08  7.926055e+08  143.037037  7.337037
# History          239.250000  5.550000e+07  2.753178e+08  157.750000  7.625000
# Horror           338.857143  3.700429e+07  2.724708e+08  116.000000  6.735714
# Mystery          321.909091  1.035455e+08  3.725879e+08  131.454545  6.827273
# Romance          236.571429  4.540020e+07  3.841570e+08  117.285714  6.400000
# Science Fiction  317.864865  1.267838e+08  5.252451e+08  126.567568  7.151351
# Thriller         290.195122  8.658537e+07  3.963394e+08  121.073171  6.995122
# War              278.666667  9.075556e+07  3.903759e+08  151.111111  7.355556
# Western          286.500000  7.983333e+07  3.360111e+08  141.500000  7.333333
#
#                   rating_count
# genre
# Action           477202.539474
# Adventure        399555.076923
# Animation        325150.920635
# Comedy           220524.127660
# Crime            223550.250000
# Drama            291762.785714
# Family           153538.357143
# Fantasy          602313.954545
# History          448652.000000
# Horror           207496.222222
# Mystery          288529.200000
# Romance          205984.269231
# Science Fiction  493352.290323
# Thriller         419500.029412
# War              411161.000000
# Western          451161.600000
# This is the least expensive genre:
#           movie_id        budget         gross     runtime    rating  \
# genre
# Action  364.136364  1.441682e+08  5.796084e+08  127.936364  6.985455
#
#          rating_count
# genre
# Action  477202.539474

# %%
print("This is the most expensive genre: ")
print(average_budget.tail(1))
# Out:
# This is the most expensive genre:
#          movie_id        budget         gross  runtime    rating  rating_count
# genre
# Western     286.5  7.983333e+07  3.360111e+08    141.5  7.333333      451161.6

# %%
# which Genre is favored the most by the people?

# action movies
